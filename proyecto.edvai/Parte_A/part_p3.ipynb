# %%
import pandas as pd

# %%
data = pd.read_csv("customer_dataset.csv", sep=',')

# %%
probando = data.copy()

# %%
data['orderAmount'], saved_bins_order = pd.qcut(data['orderAmount'], q=5, duplicates='drop', retbins=True)

# %%
import pickle
with open('saved_bins_order.pickle', 'wb') as handle:
    pickle.dump(saved_bins_order, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
data['transactionAmount'], saved_bins_order = pd.qcut(data['transactionAmount'], q=4, duplicates='drop', retbins=True)

# %%
with open('saved_bins_order.pickle', 'rb') as handle:
    new_saved_bins_order = pickle.load(handle)

# %%
import pickle
with open('saved_bins_transaction.pickle', 'wb') as handle:
    pickle.dump(saved_bins_order, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
probando["orderAmount"] = pd.cut(
    probando['orderAmount'],
    bins=new_saved_bins_order, 
    include_lowest=True) # importante para que coincidan todos

# %%
data['paymentMethodIssuer'].value_counts()
# Out:
# paymentMethodIssuer
# Her Majesty Trust           43
# Vertex Bancorp              37
# Fountain Financial Inc.     35
# His Majesty Bank Corp.      33
# Bastion Banks               29
# Bulwark Trust Corp.         29
# Citizens First Banks        28
# Grand Credit Corporation    27
# Solace Banks                27
# Rose Bancshares             25
# B                            7
# e                            5
# c                            4
# r                            3
#                              2
# n                            2
# x                            2
# o                            2
# a                            1
# p                            1
# Name: count, dtype: int64

# %%
#Reemplazar un valor a la vez
weird_payment_method = ["B", "e", "c", "r", " ", "n", "x", "o", "a", "p"]

for payment_method in weird_payment_method:
    data['paymentMethodIssuer'] = data['paymentMethodIssuer'].replace(payment_method, 'weird')

# %%
data['paymentMethodIssuer'].value_counts()
# Out:
# paymentMethodIssuer
# Her Majesty Trust           43
# Vertex Bancorp              37
# Fountain Financial Inc.     35
# His Majesty Bank Corp.      33
# Bastion Banks               29
# weird                       29
# Bulwark Trust Corp.         29
# Citizens First Banks        28
# Solace Banks                27
# Grand Credit Corporation    27
# Rose Bancshares             25
# Name: count, dtype: int64

# %%
data['paymentMethodProvider'].value_counts()
# Out:
# paymentMethodProvider
# JCB 16 digit                   65
# VISA 16 digit                  57
# Voyager                        36
# Diners Club / Carte Blanche    34
# Maestro                        32
# VISA 13 digit                  32
# Discover                       25
# American Express               22
# JCB 15 digit                   20
# Mastercard                     19
# Name: count, dtype: int64

# %%
data['paymentMethodType'].value_counts()
# Out:
# paymentMethodType
# card         242
# apple pay     36
# paypal        36
# bitcoin       28
# Name: count, dtype: int64

# %%
from funpymodeling.exploratory import freq_tbl, status, profiling_num
status(data)
# Out:
#                             variable  q_nan     p_nan  q_zeros   p_zeros  \
# 0                        orderAmount    145  0.232745        0  0.000000
# 1                         orderState    145  0.232745        0  0.000000
# 2   paymentMethodRegistrationFailure    281  0.451043      302  0.484751
# 3                  paymentMethodType    281  0.451043        0  0.000000
# 4              paymentMethodProvider    281  0.451043        0  0.000000
# 5                paymentMethodIssuer    281  0.451043        0  0.000000
# 6                  transactionAmount      0  0.000000        0  0.000000
# 7                  transactionFailed      0  0.000000      455  0.730337
# 8                         fraudulent    455  0.730337      107  0.171750
# 9                        emailDomain      0  0.000000        0  0.000000
# 10                     emailProvider      0  0.000000        0  0.000000
# 11       customerIPAddressSimplified      0  0.000000        0  0.000000
# 12                          sameCity      0  0.000000        0  0.000000
#
#     unique      type
# 0        5  category
# 1        3    object
# 2        2    object
# 3        4    object
# 4       10    object
# 5       11    object
# 6        4  category
# 7        2      bool
# 8        2    object
# 9        6    object
# 10       5    object
# 11       2    object
# 12       3    object

# %%
data['fraudulent']=data['fraudulent'].fillna(value="warning")

# %%
data["fraudulent"].value_counts()
# Out:
# fraudulent
# warning    455
# False      107
# True        61
# Name: count, dtype: int64

# %%
data['fraudulent']=data['fraudulent'].astype(str)

# %%
class_map = {'False': 0, 'True': 1, 'warning': 2}
data['fraudulent'] = data['fraudulent'].map(class_map)

# %%
data.head(3)
# Out:
#      orderAmount orderState paymentMethodRegistrationFailure  \
# 0  (9.999, 18.4]    pending                             True
# 1   (18.4, 30.0]  fulfilled                             True
# 2   (39.0, 47.0]  fulfilled                            False
#
#   paymentMethodType paymentMethodProvider   paymentMethodIssuer  \
# 0              card          JCB 16 digit  Citizens First Banks
# 1           bitcoin         VISA 16 digit          Solace Banks
# 2              card         VISA 16 digit        Vertex Bancorp
#
#   transactionAmount  transactionFailed  fraudulent emailDomain emailProvider  \
# 0     (9.999, 21.0]              False           0         com         yahoo
# 1      (21.0, 34.0]              False           1         com         yahoo
# 2      (34.0, 45.0]              False           0         com         yahoo
#
#   customerIPAddressSimplified sameCity
# 0                only_letters      yes
# 1                only_letters       no
# 2          digits_and_letters       no

# %%
data['orderAmount'].value_counts()


data['orderAmount']=data['orderAmount'].cat.add_categories("desconocido")
data['orderAmount']=data['orderAmount'].fillna(value="desconocido")

# %%
data['orderAmount'].value_counts()
# Out:
# orderAmount
# desconocido      145
# (30.0, 39.0]      98
# (39.0, 47.0]      97
# (9.999, 18.4]     96
# (18.4, 30.0]      96
# (47.0, 353.0]     91
# Name: count, dtype: int64

# %%
data_ohe = pd.get_dummies(data)

# %%
data_ohe
# Out:
#      transactionFailed  fraudulent  orderAmount_(9.999, 18.4]  \
# 0                False           0                       True
# 1                False           1                      False
# 2                False           0                      False
# 3                False           0                      False
# 4                 True           1                      False
# ..                 ...         ...                        ...
# 618               True           2                      False
# 619               True           2                      False
# 620              False           2                      False
# 621              False           2                      False
# 622              False           2                      False
#
#      orderAmount_(18.4, 30.0]  orderAmount_(30.0, 39.0]  \
# 0                       False                     False
# 1                        True                     False
# 2                       False                     False
# 3                        True                     False
# 4                       False                     False
# ..                        ...                       ...
# 618                     False                     False
# 619                     False                     False
# 620                     False                     False
# 621                     False                     False
# 622                     False                     False
#
#      orderAmount_(39.0, 47.0]  orderAmount_(47.0, 353.0]  \
# 0                       False                      False
# 1                       False                      False
# 2                        True                      False
# 3                       False                      False
# 4                        True                      False
# ..                        ...                        ...
# 618                     False                      False
# 619                     False                      False
# 620                     False                      False
# 621                     False                      False
# 622                     False                      False
#
#      orderAmount_desconocido  orderState_failed  orderState_fulfilled  ...  \
# 0                      False              False                 False  ...
# 1                      False              False                  True  ...
# 2                      False              False                  True  ...
# 3                      False              False                  True  ...
# 4                      False              False                  True  ...
# ..                       ...                ...                   ...  ...
# 618                     True              False                 False  ...
# 619                     True              False                 False  ...
# 620                     True              False                 False  ...
# 621                     True              False                 False  ...
# 622                     True              False                 False  ...
#
#      emailProvider_gmail  emailProvider_hotmail  emailProvider_other  \
# 0                  False                  False                False
# 1                  False                  False                False
# 2                  False                  False                False
# 3                  False                  False                False
# 4                  False                  False                 True
# ..                   ...                    ...                  ...
# 618                False                  False                False
# 619                False                  False                False
# 620                False                  False                False
# 621                False                  False                False
# 622                False                  False                False
#
#      emailProvider_weird  emailProvider_yahoo  \
# 0                  False                 True
# 1                  False                 True
# 2                  False                 True
# 3                  False                 True
# 4                  False                False
# ..                   ...                  ...
# 618                 True                False
# 619                 True                False
# 620                 True                False
# 621                 True                False
# 622                 True                False
#
#      customerIPAddressSimplified_digits_and_letters  \
# 0                                             False
# 1                                             False
# 2                                              True
# 3                                              True
# 4                                             False
# ..                                              ...
# 618                                           False
# 619                                           False
# 620                                           False
# 621                                           False
# 622                                           False
#
#      customerIPAddressSimplified_only_letters  sameCity_no  sameCity_unknown  \
# 0                                        True        False             False
# 1                                        True         True             False
# 2                                       False         True             False
# 3                                       False         True             False
# 4                                        True         True             False
# ..                                        ...          ...               ...
# 618                                      True        False              True
# 619                                      True        False              True
# 620                                      True        False              True
# 621                                      True        False              True
# 622                                      True        False              True
#
#      sameCity_yes
# 0            True
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 618         False
# 619         False
# 620         False
# 621         False
# 622         False
#
# [623 rows x 58 columns]

# %%
data_ohe_without_fraudulent = data_ohe.drop(["fraudulent"], axis=1)

# %%
data_ohe_without_fraudulent
# Out:
#      transactionFailed  orderAmount_(9.999, 18.4]  orderAmount_(18.4, 30.0]  \
# 0                False                       True                     False
# 1                False                      False                      True
# 2                False                      False                     False
# 3                False                      False                      True
# 4                 True                      False                     False
# ..                 ...                        ...                       ...
# 618               True                      False                     False
# 619               True                      False                     False
# 620              False                      False                     False
# 621              False                      False                     False
# 622              False                      False                     False
#
#      orderAmount_(30.0, 39.0]  orderAmount_(39.0, 47.0]  \
# 0                       False                     False
# 1                       False                     False
# 2                       False                      True
# 3                       False                     False
# 4                       False                      True
# ..                        ...                       ...
# 618                     False                     False
# 619                     False                     False
# 620                     False                     False
# 621                     False                     False
# 622                     False                     False
#
#      orderAmount_(47.0, 353.0]  orderAmount_desconocido  orderState_failed  \
# 0                        False                    False              False
# 1                        False                    False              False
# 2                        False                    False              False
# 3                        False                    False              False
# 4                        False                    False              False
# ..                         ...                      ...                ...
# 618                      False                     True              False
# 619                      False                     True              False
# 620                      False                     True              False
# 621                      False                     True              False
# 622                      False                     True              False
#
#      orderState_fulfilled  orderState_pending  ...  emailProvider_gmail  \
# 0                   False                True  ...                False
# 1                    True               False  ...                False
# 2                    True               False  ...                False
# 3                    True               False  ...                False
# 4                    True               False  ...                False
# ..                    ...                 ...  ...                  ...
# 618                 False               False  ...                False
# 619                 False               False  ...                False
# 620                 False               False  ...                False
# 621                 False               False  ...                False
# 622                 False               False  ...                False
#
#      emailProvider_hotmail  emailProvider_other  emailProvider_weird  \
# 0                    False                False                False
# 1                    False                False                False
# 2                    False                False                False
# 3                    False                False                False
# 4                    False                 True                False
# ..                     ...                  ...                  ...
# 618                  False                False                 True
# 619                  False                False                 True
# 620                  False                False                 True
# 621                  False                False                 True
# 622                  False                False                 True
#
#      emailProvider_yahoo  customerIPAddressSimplified_digits_and_letters  \
# 0                   True                                           False
# 1                   True                                           False
# 2                   True                                            True
# 3                   True                                            True
# 4                  False                                           False
# ..                   ...                                             ...
# 618                False                                           False
# 619                False                                           False
# 620                False                                           False
# 621                False                                           False
# 622                False                                           False
#
#      customerIPAddressSimplified_only_letters  sameCity_no  sameCity_unknown  \
# 0                                        True        False             False
# 1                                        True         True             False
# 2                                       False         True             False
# 3                                       False         True             False
# 4                                        True         True             False
# ..                                        ...          ...               ...
# 618                                      True        False              True
# 619                                      True        False              True
# 620                                      True        False              True
# 621                                      True        False              True
# 622                                      True        False              True
#
#      sameCity_yes
# 0            True
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 618         False
# 619         False
# 620         False
# 621         False
# 622         False
#
# [623 rows x 57 columns]

# %%
with open('categories_ohe_without_fraudulent.pickle', 'wb') as handle:
    pickle.dump(data_ohe_without_fraudulent.columns, handle, protocol=pickle.HIGHEST_PROTOCOL)
